# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
data = pd.read_csv("Crime_Data_from_2020_to_Present.csv")

# %%
data.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982638 entries, 0 to 982637
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           982638 non-null  int64
#  1   Date Rptd       982638 non-null  object
#  2   DATE OCC        982638 non-null  object
#  3   TIME OCC        982638 non-null  int64
#  4   AREA            982638 non-null  int64
#  5   AREA NAME       982638 non-null  object
#  6   Rpt Dist No     982638 non-null  int64
#  7   Part 1-2        982638 non-null  int64
#  8   Crm Cd          982638 non-null  int64
#  9   Crm Cd Desc     982638 non-null  object
#  10  Mocodes         837376 non-null  object
#  11  Vict Age        982638 non-null  int64
#  12  Vict Sex        844193 non-null  object
#  13  Vict Descent    844182 non-null  object
#  14  Premis Cd       982624 non-null  float64
#  15  Premis Desc     982053 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# DR_NO                  0
# Date Rptd              0
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Rpt Dist No            0
# Part 1-2               0
# Crm Cd                 0
# Crm Cd Desc            0
# Mocodes           145262
# Vict Age               0
# Vict Sex          138445
# Vict Descent      138456
# Premis Cd             14
# Premis Desc          585
# Weapon Used Cd    656471
# Weapon Desc       656471
# Status                 1
# Status Desc            0
# Crm Cd 1              11
# Crm Cd 2          913763
# Crm Cd 3          980327
# Crm Cd 4          982574
# LOCATION               0
# Cross Street      830789
# LAT                    0
# LON                    0
# dtype: int64

# %%
# Select numeric columns including 'Crm Cd'
numeric_columns = data.select_dtypes(include=['number'])

# Display the columns
print(numeric_columns.columns)
# Out:
# Index(['DR_NO', 'TIME OCC', 'AREA', 'Rpt Dist No', 'Part 1-2', 'Crm Cd',
#        'Vict Age', 'Premis Cd', 'Weapon Used Cd', 'Crm Cd 1', 'Crm Cd 2',
#        'Crm Cd 3', 'Crm Cd 4', 'LAT', 'LON'],
#       dtype='object')

# %%
data.columns=[i.lower() for i in data.columns]

# %%
data
# Out:
#             dr_no               date rptd                date occ  time occ  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 982633  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 982634  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 982635  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 982636  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 982637  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
# ...

# %%
data.isnull().sum()
# Out:
# dr_no                  0
# date rptd              0
# date occ               0
# time occ               0
# area                   0
# area name              0
# rpt dist no            0
# part 1-2               0
# crm cd                 0
# crm cd desc            0
# mocodes           145262
# vict age               0
# vict sex          138445
# vict descent      138456
# premis cd             14
# premis desc          585
# weapon used cd    656471
# weapon desc       656471
# status                 1
# status desc            0
# crm cd 1              11
# crm cd 2          913763
# crm cd 3          980327
# crm cd 4          982574
# location               0
# cross street      830789
# lat                    0
# lon                    0
# dtype: int64

# %%
data.drop(columns=['crm cd 2','crm cd 3','crm cd 4'],inplace=True)

# %%
data
# Out:
#             dr_no               date rptd                date occ  time occ  \
# 0       190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 3       200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# ...           ...                     ...                     ...       ...
# 982633  242011172  08/20/2024 12:00:00 AM  08/17/2024 12:00:00 AM      2300
# 982634  240710284  07/24/2024 12:00:00 AM  07/23/2024 12:00:00 AM      1400
# 982635  240104953  01/15/2024 12:00:00 AM  01/15/2024 12:00:00 AM       100
# 982636  240309674  04/24/2024 12:00:00 AM  04/24/2024 12:00:00 AM      1500
# 982637  240910892  08/13/2024 12:00:00 AM  08/12/2024 12:00:00 AM      2300
#
# ...

# %%
mean=data['crm cd 1'].mean()

# %%
data['crm cd 1'].fillna(mean,inplace=True)

# %%
data.isnull().sum()
# Out:
# dr_no                  0
# date rptd              0
# date occ               0
# time occ               0
# area                   0
# area name              0
# rpt dist no            0
# part 1-2               0
# crm cd                 0
# crm cd desc            0
# mocodes           145262
# vict age               0
# vict sex          138445
# vict descent      138456
# premis cd             14
# premis desc          585
# weapon used cd    656471
# weapon desc       656471
# status                 1
# status desc            0
# crm cd 1               0
# location               0
# cross street      830789
# lat                    0
# lon                    0
# dtype: int64

# %%
data.drop(columns=['cross street','mocodes'],inplace=True)

# %% [markdown]
# ###preprocessing

# %% [markdown]
# encoding=one hot encoding,label encoding,ordinal encoding,get dummies,frequency encoding,binary encoding, manual encoding

# %%
mode=data['status'].mode()

# %%
data['new status']=data['status'].fillna('IC')

# %%
data.isnull().sum()
# Out:
# dr_no                  0
# date rptd              0
# date occ               0
# time occ               0
# area                   0
# area name              0
# rpt dist no            0
# part 1-2               0
# crm cd                 0
# crm cd desc            0
# vict age               0
# vict sex          138445
# vict descent      138456
# premis cd             14
# premis desc          585
# weapon used cd    656471
# weapon desc       656471
# status                 1
# status desc            0
# crm cd 1               0
# location               0
# lat                    0
# lon                    0
# new status             0
# dtype: int64

# %%
data.drop(columns='status',inplace=True)

# %%
data.isnull().sum()
# Out:
# dr_no                  0
# date rptd              0
# date occ               0
# time occ               0
# area                   0
# area name              0
# rpt dist no            0
# part 1-2               0
# crm cd                 0
# crm cd desc            0
# vict age               0
# vict sex          138445
# vict descent      138456
# premis cd             14
# premis desc          585
# weapon used cd    656471
# weapon desc       656471
# status desc            0
# crm cd 1               0
# location               0
# lat                    0
# lon                    0
# new status             0
# dtype: int64

# %%
data['premis desc'].mode()
# Out:
# 0    STREET
# Name: premis desc, dtype: object

# %%
data['premis desc'].fillna('STREET',inplace=True)

# %%
data.isnull().sum()
# Out:
# dr_no                  0
# date rptd              0
# date occ               0
# time occ               0
# area                   0
# area name              0
# rpt dist no            0
# part 1-2               0
# crm cd                 0
# crm cd desc            0
# vict age               0
# vict sex          138445
# vict descent      138456
# premis cd             14
# premis desc            0
# weapon used cd    656471
# weapon desc       656471
# status desc            0
# crm cd 1               0
# location               0
# lat                    0
# lon                    0
# new status             0
# dtype: int64

# %%
data['premis cd'].mean()
# Out:
# 306.1330081496076

# %%
data['premis cd'].fillna(306.1330081496076, inplace=True)

# %%
data.isnull().sum()
# Out:
# dr_no                  0
# date rptd              0
# date occ               0
# time occ               0
# area                   0
# area name              0
# rpt dist no            0
# part 1-2               0
# crm cd                 0
# crm cd desc            0
# vict age               0
# vict sex          138445
# vict descent      138456
# premis cd              0
# premis desc            0
# weapon used cd    656471
# weapon desc       656471
# status desc            0
# crm cd 1               0
# location               0
# lat                    0
# lon                    0
# new status             0
# dtype: int64

# %%
data['vict sex'].mode()
# Out:
# 0    M
# Name: vict sex, dtype: object

# %%
data['vict sex'].fillna('M', inplace=True)

# %%
data['vict descent'].mode()
# Out:
# 0    H
# Name: vict descent, dtype: object

# %%
data['vict descent'].fillna('H',inplace=True)

# %%
data.isnull().sum()
# Out:
# dr_no                  0
# date rptd              0
# date occ               0
# time occ               0
# area                   0
# area name              0
# rpt dist no            0
# part 1-2               0
# crm cd                 0
# crm cd desc            0
# vict age               0
# vict sex               0
# vict descent           0
# premis cd              0
# premis desc            0
# weapon used cd    656471
# weapon desc       656471
# status desc            0
# crm cd 1               0
# location               0
# lat                    0
# lon                    0
# new status             0
# dtype: int64

# %%
data['weapon used cd'].mean()
# Out:
# 363.8408821248011

# %%
data['weapon used cd'].fillna(363.8408821248011, inplace=True)

# %%
data['weapon desc'].mode()
# Out:
# 0    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# Name: weapon desc, dtype: object

# %%
data.drop(columns=['weapon desc'], inplace=True)

# %%
data.isnull().sum()
# Out:
# dr_no             0
# date rptd         0
# date occ          0
# time occ          0
# area              0
# area name         0
# rpt dist no       0
# part 1-2          0
# crm cd            0
# crm cd desc       0
# vict age          0
# vict sex          0
# vict descent      0
# premis cd         0
# premis desc       0
# weapon used cd    0
# status desc       0
# crm cd 1          0
# location          0
# lat               0
# lon               0
# new status        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982638 entries, 0 to 982637
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   dr_no           982638 non-null  int64
#  1   date rptd       982638 non-null  object
#  2   date occ        982638 non-null  object
#  3   time occ        982638 non-null  int64
#  4   area            982638 non-null  int64
#  5   area name       982638 non-null  object
#  6   rpt dist no     982638 non-null  int64
#  7   part 1-2        982638 non-null  int64
#  8   crm cd          982638 non-null  int64
#  9   crm cd desc     982638 non-null  object
#  10  vict age        982638 non-null  int64
#  11  vict sex        982638 non-null  object
#  12  vict descent    982638 non-null  object
#  13  premis cd       982638 non-null  float64
#  14  premis desc     982638 non-null  object
#  15  weapon used cd  982638 non-null  float64
# ...

# %%
l_e = LabelEncoder()

# %%
data = data.apply(lambda col: l_e.fit_transform(col) if col.dtype == 'object' else col)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 982638 entries, 0 to 982637
# Data columns (total 22 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   dr_no           982638 non-null  int64
#  1   date rptd       982638 non-null  int32
#  2   date occ        982638 non-null  int32
#  3   time occ        982638 non-null  int64
#  4   area            982638 non-null  int64
#  5   area name       982638 non-null  int32
#  6   rpt dist no     982638 non-null  int64
#  7   part 1-2        982638 non-null  int64
#  8   crm cd          982638 non-null  int64
#  9   crm cd desc     982638 non-null  int32
#  10  vict age        982638 non-null  int64
#  11  vict sex        982638 non-null  int32
#  12  vict descent    982638 non-null  int32
#  13  premis cd       982638 non-null  float64
#  14  premis desc     982638 non-null  int32
#  15  weapon used cd  982638 non-null  float64
#  16  status desc     982638 non-null  int32
# ...

# %%
data.corr()
# Out:
#                    dr_no  date rptd  date occ  time occ      area  area name  \
# dr_no           1.000000  -0.128227 -0.103958 -0.004952  0.036684   0.004827
# date rptd      -0.128227   1.000000  0.919070 -0.000820 -0.006675  -0.001432
# date occ       -0.103958   0.919070  1.000000  0.002765 -0.007312  -0.001713
# time occ       -0.004952  -0.000820  0.002765  1.000000  0.001061   0.010618
# area            0.036684  -0.006675 -0.007312  0.001061  1.000000   0.050323
# area name       0.004827  -0.001432 -0.001713  0.010618  0.050323   1.000000
# rpt dist no     0.036909  -0.006626 -0.007265  0.001184  0.999050   0.046699
# part 1-2       -0.027919  -0.007487 -0.012738 -0.056143  0.007005  -0.010764
# crm cd         -0.018565  -0.002682 -0.003613  0.011562 -0.006050  -0.008111
# crm cd desc     0.065972   0.000306 -0.001153 -0.006708  0.018309   0.018723
# vict age       -0.058325  -0.006253 -0.007344 -0.034922  0.022130   0.037746
# ...

# %%
corr=data.corr()['crm cd'].sort_values(ascending=False)

# %%
corr
# Out:
# crm cd            1.000000
# crm cd 1          0.999314
# part 1-2          0.699915
# weapon used cd    0.245549
# crm cd desc       0.141190
# premis cd         0.117520
# premis desc       0.067777
# lon               0.039158
# time occ          0.011562
# date rptd        -0.002682
# date occ         -0.003613
# area             -0.006050
# rpt dist no      -0.006177
# vict descent     -0.007298
# area name        -0.008111
# dr_no            -0.018565
# vict age         -0.019592
# location         -0.023801
# lat              -0.039055
# vict sex         -0.070339
# status desc      -0.104048
# new status       -0.124819
# Name: crm cd, dtype: float64

# %%
y=data['crm cd']

# %%
x=data.drop('crm cd',axis=1)

# %%
y
# Out:
# 0         510
# 1         330
# 2         480
# 3         343
# 4         354
#          ...
# 982633    341
# 982634    510
# 982635    745
# 982636    230
# 982637    510
# Name: crm cd, Length: 982638, dtype: int64

# %%
x
# Out:
#             dr_no  date rptd  date occ  time occ  area  area name  \
# 0       190326475        297       297      2130     7         20
# 1       200106753        195       190      1800     1          1
# 2       200320258       1531      1503      1700     3         15
# 3       200907217        650       342      2037     9         17
# 4       220614831       1149      1142      1200     6          6
# ...           ...        ...       ...       ...   ...        ...
# 982633  242011172       1161      1146      2300    20         11
# 982634  240710284       1026      1021      1400     7         20
# 982635  240104953         74        74       100     1          1
# 982636  240309674        571       571      1500     3         15
# 982637  240910892       1126      1121      2300     9         17
#
#         rpt dist no  part 1-2  crm cd desc  vict age  ...  vict descent  \
# 0               784         1          134         0  ...            12
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=SVC()
